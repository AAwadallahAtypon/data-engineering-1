# %%
#!pip install faker

from faker import Faker
import csv
output=open('/home/csv_data/data.csv','w')
fake=Faker()
header=['name','age','street','city','state','zip','lng','lat']
mywriter=csv.writer(output)
mywriter.writerow(header)
for r in range(100):
    row =[fake.name(),fake.random_int(min=18,max=80, step=1), 
                       fake.street_address(), fake.city(),fake.state(),
                       fake.zipcode(),fake.longitude(),fake.latitude()]
    print(row)
    mywriter.writerow(row)

output.close()
# Out:
# ['Derek Lewis', 60, '895 Morris Port', 'Joshuashire', 'New Hampshire', '03827', Decimal('-65.726070'), Decimal('7.7878945')]
# ['Jose Fischer', 28, '44029 Ashley Center', 'West Jennymouth', 'Hawaii', '05410', Decimal('174.147583'), Decimal('51.7107785')]
# ['Rita Carter', 39, '36114 Wang Falls', 'Flynnfort', 'New Hampshire', '90344', Decimal('133.081059'), Decimal('-68.0788425')]
# ['Charles Terry', 39, '71751 Frank Locks Apt. 914', 'New Jennifer', 'New Hampshire', '24363', Decimal('-67.014972'), Decimal('20.4465105')]
# ['Kimberly Byrd', 30, '441 Kimberly Tunnel', 'Sharifort', 'Hawaii', '31071', Decimal('179.189358'), Decimal('-68.899720')]
# ['Hannah Miller', 46, '8266 Tracy Burgs', 'Port Coreymouth', 'Illinois', '27156', Decimal('33.728986'), Decimal('-30.8837775')]
# ['Ryan Campbell', 21, '078 Brenda Heights', 'Fordhaven', 'Louisiana', '99441', Decimal('157.661083'), Decimal('-86.4934905')]
# ['Kristen Cohen', 21, '9275 Jessica Mount Suite 935', 'East Patriciaport', 'Minnesota', '94879', Decimal('13.761443'), Decimal('-49.7957945')]
# ['Ernest Garcia', 49, '8280 Debra Crest', 'South Kathryn', 'Montana', '05218', Decimal('148.909889'), Decimal('-25.1748175')]
# ['Monique Jenkins', 23, '568 Richard Throughway', 'Port Kimberlymouth', 'Oklahoma', '92544', Decimal('42.309786'), Decimal('-81.7709365')]
# ['Hannah Gonzalez', 36, '046 Boyer Port Apt. 652', 'Lake Anthonyport', 'Nebraska', '06647', Decimal('8.830636'), Decimal('-77.9125825')]
# ['Jason Gonzalez', 51, '93563 Cameron Loop', 'Angelatown', 'Delaware', '98534', Decimal('-79.262127'), Decimal('-80.1348615')]
# ['Joan Clayton', 76, '1192 Joann Lakes Apt. 056', 'Lake Amanda', 'Alaska', '76897', Decimal('91.155313'), Decimal('-15.2970915')]
# ['Clifford Wilson', 61, '86985 Allen Fork', 'New Kimberly', 'Michigan', '35982', Decimal('113.827442'), Decimal('-38.980790')]
# ['Heather Taylor', 51, '6950 Heather Shore', 'Marthabury', 'Indiana', '96631', Decimal('35.943702'), Decimal('-9.574375')]
# ['Eric Garcia', 18, '81764 Angela Extension', 'Lake Rebeccaborough', 'Nevada', '09765', Decimal('38.775014'), Decimal('-15.044690')]
# ['Kaitlyn Taylor', 52, '1983 Graves Estates', 'North Andrew', 'Nevada', '85721', Decimal('28.722041'), Decimal('-65.0616545')]
# ['Kendra Kelly', 30, '21098 Donald Heights Apt. 920', 'Bowersborough', 'Illinois', '13389', Decimal('-78.390220'), Decimal('76.6869935')]
# ['Alexander Moody', 57, '570 Hunter Ridges', 'Port Josephton', 'Louisiana', '26215', Decimal('36.553116'), Decimal('-43.202623')]
# ['Jasmine Johns', 47, '37818 Tommy Island', 'Wallaceshire', 'Maine', '20366', Decimal('117.053404'), Decimal('86.8537735')]
# ['Joshua Rivera', 76, '2287 Bradford Glen', 'Angelicamouth', 'Missouri', '95737', Decimal('176.274616'), Decimal('69.7202845')]
# ['Kathy Boyer', 29, '7857 Smith Pike Apt. 835', 'North Biancatown', 'Rhode Island', '90349', Decimal('97.632707'), Decimal('-58.6321975')]
# ['Samuel Walker', 45, '1411 Li Mews', 'South Stevenport', 'Minnesota', '48695', Decimal('57.034260'), Decimal('70.467168')]
# ['Craig Anderson', 42, '985 Bennett Rapid', 'Amberstad', 'Virginia', '99408', Decimal('-90.885778'), Decimal('-68.385799')]
# ['Chelsea James', 72, '70532 Yvonne Drives', 'Rodriguezfurt', 'Colorado', '44361', Decimal('-25.271119'), Decimal('55.563856')]
# ['Jason Cox', 29, '4794 Lucas Stream Suite 809', 'North Krista', 'Nebraska', '22884', Decimal('-102.749479'), Decimal('83.3654845')]
# ['Michele Spencer', 41, '2042 John Corner', 'West Christopher', 'New York', '08949', Decimal('47.218973'), Decimal('-4.600929')]
# ['Andrea Vaughn', 60, '408 Deborah Spring Apt. 182', 'New Samanthaport', 'Colorado', '13717', Decimal('27.049035'), Decimal('-76.3380355')]
# ['Tammy Meyer', 35, '6797 Kane Lights', 'Jacquelinemouth', 'California', '11946', Decimal('-14.324682'), Decimal('20.346761')]
# ['Savannah Rodriguez', 76, '279 Brown Roads Apt. 077', 'Shafferfurt', 'Kansas', '67171', Decimal('80.085818'), Decimal('-25.786916')]
# ['John Hanson', 63, '1554 Brandon Terrace', 'North Marisaland', 'Virginia', '71934', Decimal('145.065340'), Decimal('58.9813645')]
# ['Christopher Walter', 21, '01993 Marisa Underpass', 'East Dylan', 'Indiana', '51564', Decimal('-30.162860'), Decimal('82.9031105')]
# ['Jennifer Savage', 64, '0514 Lori Roads Suite 053', 'Fuentesside', 'Arizona', '01376', Decimal('140.974830'), Decimal('21.850152')]
# ['Nicholas Watkins', 39, '35980 Taylor Alley Apt. 061', 'Kristenshire', 'Idaho', '21576', Decimal('164.491212'), Decimal('12.011876')]
# ['Taylor Mills', 78, '990 Wright Ways Suite 341', 'Teresahaven', 'North Carolina', '05569', Decimal('97.025620'), Decimal('27.6765745')]
# ['Karen Holden', 56, '30917 Saunders Freeway Apt. 888', 'Taylorport', 'Minnesota', '11888', Decimal('-100.311074'), Decimal('27.627251')]
# ['Kristina Thomas', 28, '08410 Kathy Plaza', 'Deborahport', 'Texas', '96911', Decimal('160.477438'), Decimal('13.757841')]
# ['Wendy Callahan', 77, '335 Steven Junctions Suite 666', 'New Andreamouth', 'Illinois', '07707', Decimal('46.572109'), Decimal('-14.422541')]
# ['Ronald Scott', 72, '6210 Gordon Lane', 'Dianaville', 'New York', '29055', Decimal('-149.707573'), Decimal('66.810107')]
# ['Daniel Harris', 77, '201 Lewis Forest Suite 248', 'Victoriaburgh', 'Wisconsin', '43890', Decimal('-173.445569'), Decimal('-55.6519195')]
# ['Brian Anderson', 23, '6830 White Extensions', 'Kellyhaven', 'Louisiana', '84253', Decimal('-33.854172'), Decimal('78.3826985')]
# ['Sean Jones', 70, '599 Brittany Forge Apt. 037', 'Courtneyshire', 'Arkansas', '30901', Decimal('-108.219255'), Decimal('69.893467')]
# ['Kelly Morgan', 77, '1082 Emma Streets', 'South Reneefort', 'New Jersey', '61569', Decimal('-151.697813'), Decimal('-65.6193275')]
# ['Pamela Campos', 77, '8727 Castro Street', 'Taylorside', 'Florida', '45878', Decimal('22.705026'), Decimal('39.699659')]
# ['Tina Bryan', 62, '704 Fleming Keys Suite 485', 'Piercefurt', 'Iowa', '05315', Decimal('-160.215874'), Decimal('13.461719')]
# ['Chelsey Porter', 58, '378 Barry Underpass Apt. 171', 'Brianton', 'Mississippi', '07816', Decimal('-59.209912'), Decimal('-27.8136465')]
# ['Ronald Riley', 60, '04045 Ashley Drives Suite 558', 'Chanbury', 'Florida', '60995', Decimal('22.822875'), Decimal('14.180340')]
# ['Jacob Aguilar', 39, '2822 Alan Wall Apt. 056', 'West Nicholasbury', 'South Carolina', '11379', Decimal('141.091683'), Decimal('-54.853126')]
# ['Eric Baker', 36, '68329 Noah Overpass Apt. 152', 'Johnside', 'Massachusetts', '56996', Decimal('-169.323787'), Decimal('1.673010')]
# ['Jennifer Medina', 24, '14961 Acosta Way Apt. 106', 'West William', 'Utah', '17469', Decimal('-11.350916'), Decimal('64.9828825')]
# ['Charles Foster', 62, '666 Jones Freeway', 'Freemanview', 'Arizona', '08894', Decimal('-153.682566'), Decimal('-26.329850')]
# ['Samantha Simpson', 71, '68916 Wood Mill Suite 388', 'South Keith', 'Virginia', '19907', Decimal('-40.560694'), Decimal('-10.031750')]
# ['Albert Fernandez', 48, '038 White Point Apt. 299', 'Hartmouth', 'Oregon', '11915', Decimal('-84.759003'), Decimal('12.267858')]
# ['Madeline Pruitt', 43, '81659 Silva Inlet Suite 256', 'Port Andrea', 'Alabama', '38177', Decimal('94.664952'), Decimal('-89.8836275')]
# ['Joshua Chan', 23, '791 Spears Spurs', 'Smithport', 'Kansas', '38505', Decimal('107.976234'), Decimal('2.0344595')]
# ['David Myers', 27, '21916 Chelsea Islands', 'North Connieland', 'Colorado', '39664', Decimal('-78.923673'), Decimal('-4.100248')]
# ['Lauren Harmon', 74, '243 Caitlyn Roads Apt. 728', 'Lake David', 'South Carolina', '28988', Decimal('135.492808'), Decimal('-48.1321685')]
# ['David Marsh', 58, '3148 Angela Isle Apt. 516', 'Patriciaton', 'Massachusetts', '29880', Decimal('-103.792861'), Decimal('-45.916683')]
# ['Alexandria White', 64, '1247 Aimee Club Apt. 597', 'Hollyland', 'California', '93560', Decimal('-65.695805'), Decimal('-84.2145455')]
# ['Marcia Torres', 79, '92388 Vincent Square Apt. 245', 'Mauricestad', 'Alabama', '86648', Decimal('146.417090'), Decimal('-78.150197')]
# ['Brooke Graham', 42, '942 Joshua Shores Suite 791', 'Port Traceymouth', 'Rhode Island', '26731', Decimal('-30.554891'), Decimal('-3.047580')]
# ['Elizabeth White', 31, '3539 Mark Run', 'Nicholsburgh', 'Missouri', '03450', Decimal('-127.387336'), Decimal('56.556684')]
# ['John Santiago', 45, '936 Alexander Island', 'Port Jessehaven', 'Connecticut', '09707', Decimal('-48.636029'), Decimal('-80.3670555')]
# ['John Morrow', 28, '3514 Megan Neck', 'Lake Amy', 'Ohio', '79383', Decimal('1.581368'), Decimal('0.950875')]
# ['Mark Richards', 39, '15939 Tracy Lane', 'Wardfort', 'Kentucky', '99065', Decimal('102.242812'), Decimal('38.001508')]
# ['Steven Oneill', 61, '689 John Rapids Suite 194', 'North Alishaville', 'Wisconsin', '14712', Decimal('41.678238'), Decimal('-38.6237275')]
# ['Brian Kerr', 32, '30642 Willis Parkways', 'West Wendyland', 'New Jersey', '26237', Decimal('138.401156'), Decimal('-70.609940')]
# ['Ronald Burton', 18, '78883 Trevor Oval', 'Amyton', 'Connecticut', '31021', Decimal('-132.850877'), Decimal('30.8572705')]
# ['Jonathan Dean', 27, '004 Adams Run', 'Reyesmouth', 'Oregon', '82508', Decimal('104.890330'), Decimal('75.6564185')]
# ['Elizabeth Hudson', 73, '98768 Jeff Row', 'Emilymouth', 'Virginia', '57234', Decimal('51.889521'), Decimal('-75.2346435')]
# ['Scott Green', 66, '8411 Nixon Light', 'East Zachary', 'Delaware', '56228', Decimal('-33.703529'), Decimal('24.062101')]
# ['Marcus Shea', 54, '5491 Abbott Village Apt. 924', 'Lake Jeffrey', 'Missouri', '61051', Decimal('-134.981720'), Decimal('86.367510')]
# ['Philip Butler', 37, '34310 Patrick Fords', 'East Julie', 'Alabama', '86089', Decimal('156.226030'), Decimal('-4.3015335')]
# ['Brian Cox MD', 58, '786 Turner Crossroad Suite 140', 'New George', 'Montana', '26272', Decimal('-133.809772'), Decimal('16.304925')]
# ['Sarah Weaver', 29, '300 Jason Grove Apt. 646', 'Samanthahaven', 'Louisiana', '29744', Decimal('-125.432963'), Decimal('48.6031595')]
# ['Kenneth Shaw', 27, '862 Jessica Prairie Apt. 612', 'Port Sarahmouth', 'Idaho', '54641', Decimal('-17.071712'), Decimal('65.2769995')]
# ['Travis Banks', 64, '1990 Susan Freeway', 'West Robertfurt', 'Alaska', '64433', Decimal('-136.282827'), Decimal('-84.0644225')]
# ['Jeff Garcia', 57, '59616 Michelle Inlet', 'North Timothy', 'Arizona', '29659', Decimal('-3.976211'), Decimal('-34.4867515')]
# ['Teresa Robinson', 76, '3755 Campbell Mountain', 'Daniellemouth', 'Wisconsin', '10005', Decimal('-40.126573'), Decimal('74.891552')]
# ['Thomas Travis', 46, '69313 Thomas Divide Apt. 011', 'Hunterfort', 'Vermont', '05204', Decimal('177.660264'), Decimal('59.9957615')]
# ['Elizabeth Sanchez', 46, '264 Timothy Orchard Apt. 067', 'Dianachester', 'New Mexico', '96446', Decimal('20.772469'), Decimal('30.7355785')]
# ['Jason Brown II', 76, '22142 Thomas Falls', 'West Brentland', 'Arizona', '77394', Decimal('-157.068513'), Decimal('-17.2384525')]
# ['Jordan Wade', 21, '684 Taylor Wall Suite 381', 'New Kevinside', 'New Mexico', '60344', Decimal('-123.107687'), Decimal('69.452952')]
# ['David Garcia', 50, '7925 Jeffrey Extensions', 'Lake Josephfurt', 'Missouri', '32951', Decimal('-42.902416'), Decimal('-48.3675655')]
# ['Michael Green', 48, '405 Bianca Island', 'Lake Kyleside', 'New Hampshire', '45618', Decimal('59.004943'), Decimal('-69.300394')]
# ['Jessica Henderson', 39, '839 Ingram Prairie Suite 356', 'North Christopherton', 'Maryland', '80187', Decimal('112.166952'), Decimal('77.1084655')]
# ['Kristen Ryan', 54, '442 Nancy Mountains', 'Donnaton', 'Colorado', '03956', Decimal('-120.527120'), Decimal('86.421793')]
# ['Keith Wade', 51, '858 Schneider Lodge Apt. 355', 'Rossland', 'South Dakota', '51664', Decimal('34.433588'), Decimal('-8.238415')]
# ['Christopher Holmes', 24, '81812 Lisa Glen Apt. 019', 'Millertown', 'Texas', '12572', Decimal('91.516946'), Decimal('0.736530')]
# ['Joel Moore', 34, '6672 Dominique Bridge Apt. 104', 'Wrightfurt', 'Kansas', '21984', Decimal('172.681984'), Decimal('-6.596716')]
# ['Christopher Scott', 26, '69564 Chad Locks Suite 747', 'Port Markville', 'Wisconsin', '17920', Decimal('-41.783159'), Decimal('-39.177355')]
# ['Roger Andersen', 75, '636 Eric River', 'Dukeborough', 'Maine', '41222', Decimal('-96.010480'), Decimal('-1.668969')]
# ['Joseph Parrish', 27, '8203 Larry Forges', 'Michelleview', 'Massachusetts', '10775', Decimal('130.610588'), Decimal('27.664921')]
# ['Wayne George', 51, '8960 Nicholas Course Suite 718', 'Wrighttown', 'Utah', '58589', Decimal('-59.095743'), Decimal('10.1736915')]
# ['Robert Walker', 30, '8102 Smith Vista Apt. 692', 'Jamesshire', 'Indiana', '48782', Decimal('26.098009'), Decimal('-43.7612985')]
# ['Lauren Kim', 20, '634 Chelsea Brook', 'New Danielle', 'North Carolina', '52235', Decimal('-85.927020'), Decimal('10.041500')]
# ['Dana Brown', 47, '27236 Sandra Divide Apt. 457', 'North Matthewtown', 'California', '81809', Decimal('18.566090'), Decimal('39.1874965')]
# ['Melissa Mitchell', 49, '77872 Yates Circle Apt. 428', 'Harrellburgh', 'Arizona', '66943', Decimal('37.031444'), Decimal('-68.2813015')]
# ['Brandon Browning', 49, '48529 Jason Common', 'Port Cindyshire', 'New Jersey', '41678', Decimal('-98.124110'), Decimal('-34.250028')]
# ['Sara Parks', 50, '483 Donovan Knolls Suite 343', 'Camachohaven', 'Washington', '02351', Decimal('-76.156895'), Decimal('-88.1903235')]
